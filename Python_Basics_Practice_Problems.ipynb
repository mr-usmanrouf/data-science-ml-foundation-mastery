# %% [markdown]
# # SUZH Python Fundamentals
#
# **Created By SUZH TEAM**
#
# **Special Thanks to Muhammad Usman Rouf, CEO of SUZH**

# %% [markdown]
# ### How This Workbook Works
#
# This is **Level 0** of the SUZH curriculum -- pure fundamentals, no shortcuts assumed. 105 problems across 9 topics: variables, operators, conditionals, loops, shorthand if-else, functions, lists, tuples, and exception handling. Problems are ordered from simplest to slightly harder within each topic, so the last one or two in every section are a small stretch on purpose.
#
# No solutions are included. Write the code in the cell directly below each problem, run it, and check the output makes sense by hand before moving on.
#
# **Finished this notebook?** The next step up is the *SUZH Python Mastery Curriculum* (105 problems, Basic/Intermediate/Advanced across 7 intermediate-to-advanced topics) -- that's where this workbook is designed to hand you off.

# %% [markdown]
# ## Topic 1: Variables & Basic I/O

# %% [markdown]
# **Problem 1:** Create a variable named `age` and assign it your age. Print its value.

# %% [markdown]
# **Problem 2:** Create two variables `a` and `b`, assign them the values 10 and 20, then swap their values without using a third variable.

# %% [markdown]
# **Problem 3:** Take the user's name as input and print a greeting message: 'Hello, <name>!'

# %% [markdown]
# **Problem 4:** Take two numbers as input from the user and print their sum.

# %% [markdown]
# **Problem 5:** Create a variable `radius` with the value 5, and print the area of a circle using the formula πr² (use 3.14 for π).

# %% [markdown]
# **Problem 6:** Write a program that stores your name, age, and city in three separate variables, then prints them all in a single formatted sentence.

# %% [markdown]
# **Problem 7:** Check and print the data type of each of the following values using `type()`: 10, 10.5, 'Hello', True.

# %% [markdown]
# **Problem 8:** Take the temperature in Celsius as input and convert it to Fahrenheit using the formula F = (C × 9/5) + 32.

# %% [markdown]
# **Problem 9:** Create a variable `price` with the value 250.75, and print it rounded to the nearest whole number using `round()`.

# %% [markdown]
# **Problem 10:** Take a user's height in centimeters as input and convert it to meters, printing the result.

# %% [markdown]
# ## Topic 2: Operators

# %% [markdown]
# **Problem 11:** Take two numbers as input and print the results of addition, subtraction, multiplication, and division.

# %% [markdown]
# **Problem 12:** Take two numbers as input and print the quotient and remainder using the `//` and `%` operators.

# %% [markdown]
# **Problem 13:** Write a program to calculate the area and perimeter of a rectangle, given its length and width as input.

# %% [markdown]
# **Problem 14:** Take two numbers as input and print True or False for each of these comparisons: equal to, not equal to, greater than, less than.

# %% [markdown]
# **Problem 15:** Take three numbers as input and check, using the `and` operator, whether ALL three are positive.

# %% [markdown]
# **Problem 16:** Write a program that takes a number, increases it by 5 using the `+=` shorthand operator, then prints the updated value.

# %% [markdown]
# **Problem 17:** Take a base and an exponent as input, and calculate the result using the exponentiation operator `**`.

# %% [markdown]
# **Problem 18:** Take a number as input and use the `%` operator to check whether it is exactly divisible by both 3 and 5.

# %% [markdown]
# **Problem 19:** Take two boolean values as input (as 0 or 1, then convert to `bool`) and print the result of applying `and`, `or`, and `not` to them.

# %% [markdown]
# **Problem 20:** Given the expression `10 + 2 * 3 - 4 / 2`, first predict the result on paper using operator precedence rules, then print the expression's actual value to check your prediction.

# %% [markdown]
# ## Topic 3: Conditional Statements (if / elif / else)

# %% [markdown]
# **Problem 21:** Write a program to check whether a number is even or odd.

# %% [markdown]
# **Problem 22:** Write a program to check whether a given number is positive, negative, or zero.

# %% [markdown]
# **Problem 23:** Write a program to find the larger of two numbers using if-else.

# %% [markdown]
# **Problem 24:** Write a program to find the largest of three numbers using if-elif-else.

# %% [markdown]
# **Problem 25:** Write a program to check whether a given year is a leap year.

# %% [markdown]
# **Problem 26:** Write a program that takes a student's marks as input and prints the grade: A (90+), B (75-89), C (60-74), or F (below 60).

# %% [markdown]
# **Problem 27:** Write a program to check whether a given character is a vowel or a consonant.

# %% [markdown]
# **Problem 28:** Write a program to check whether a triangle is valid, given its three angles as input (valid if all three angles are positive and they sum to exactly 180).

# %% [markdown]
# **Problem 29:** Write a program that takes a person's age as input and prints whether they are eligible to vote (age 18 or above).

# %% [markdown]
# **Problem 30:** Write a program to check whether a given number is divisible by both 2 and 3, only 2, only 3, or neither.

# %% [markdown]
# **Problem 31:** Write a program that takes three side lengths as input and determines whether they can form a valid triangle (the sum of any two sides must be greater than the third).

# %% [markdown]
# **Problem 32:** Write a program to categorize a given BMI value into Underweight (below 18.5), Normal (18.5-24.9), Overweight (25-29.9), or Obese (30 and above).

# %% [markdown]
# ## Topic 4: Loops (for / while)

# %% [markdown]
# **Problem 33:** Write a program to print all numbers from 1 to 20 using a for loop.

# %% [markdown]
# **Problem 34:** Write a program to print all even numbers between 1 and 50 using a for loop.

# %% [markdown]
# **Problem 35:** Write a program to calculate the factorial of a given number using a for loop.

# %% [markdown]
# **Problem 36:** Write a program to calculate the sum of the first N natural numbers using a while loop.

# %% [markdown]
# **Problem 37:** Write a program to print the multiplication table (1 to 10) of a number given as input.

# %% [markdown]
# **Problem 38:** Write a program to reverse a given number (e.g., 1234 becomes 4321) using a while loop.

# %% [markdown]
# **Problem 39:** Write a program to check whether a given number is a prime number using a for loop.

# %% [markdown]
# **Problem 40:** Write a program to print the first N terms of the Fibonacci sequence using a for loop.

# %% [markdown]
# **Problem 41:** Write a program to count the number of digits in a given number using a while loop.

# %% [markdown]
# **Problem 42:** Write a program to check whether a given number is a palindrome (reads the same forwards and backwards).

# %% [markdown]
# **Problem 43:** Write a program that uses `break` to stop a loop as soon as it finds the first number divisible by 7 within a given range.

# %% [markdown]
# **Problem 44:** Write a program that uses `continue` to print all numbers from 1 to 20 EXCEPT multiples of 3.

# %% [markdown]
# **Problem 45:** Write a program using nested loops to print this pattern:
# ```
# *
# **
# ***
# ****
# *****
# ```

# %% [markdown]
# **Problem 46:** Write a program to calculate the sum of the digits of a given number.

# %% [markdown]
# **Problem 47:** Write a program to print numbers from 100 down to 1 (counting backward) using a while loop.

# %% [markdown]
# ## Topic 5: Shorthand If-Else (Ternary Operator)

# %% [markdown]
# **Problem 48:** Rewrite this logic using a shorthand (ternary) if-else in a single line: check whether a number is even or odd.

# %% [markdown]
# **Problem 49:** Write a one-line shorthand if-else statement to find the larger of two numbers.

# %% [markdown]
# **Problem 50:** Write a one-line shorthand if-else statement to label a given age as 'Minor' or 'Adult' (18+).

# %% [markdown]
# **Problem 51:** Write a one-line shorthand if-else statement to print 'Pass' or 'Fail' based on whether a score is 40 or above.

# %% [markdown]
# **Problem 52:** Rewrite this logic using shorthand if-else: check if a number is positive or non-positive.

# %% [markdown]
# **Problem 53:** Write a one-line shorthand if-else statement to check whether a given string is empty or not.

# %% [markdown]
# **Problem 54:** Write a one-line shorthand if-else statement to find the absolute value of a number without using the built-in `abs()` function.

# %% [markdown]
# **Problem 55:** Write a one-line shorthand if-else statement to check whether a number is divisible by 4.

# %% [markdown]
# ## Topic 6: Functions

# %% [markdown]
# **Problem 56:** Write a function `greet(name)` that takes a name as a parameter and returns a greeting message.

# %% [markdown]
# **Problem 57:** Write a function `add(a, b)` that returns the sum of two numbers, and call it with two different pairs of values.

# %% [markdown]
# **Problem 58:** Write a function `is_even(n)` that returns True if a number is even and False otherwise.

# %% [markdown]
# **Problem 59:** Write a function `factorial(n)` that returns the factorial of a given number using a loop.

# %% [markdown]
# **Problem 60:** Write a function `find_max(a, b, c)` that returns the largest of three numbers.

# %% [markdown]
# **Problem 61:** Write a function `check_prime(n)` that returns True if a number is prime, False otherwise.

# %% [markdown]
# **Problem 62:** Write a function `celsius_to_fahrenheit(c)` that converts and returns the Fahrenheit equivalent of a Celsius temperature.

# %% [markdown]
# **Problem 63:** Write a function `greet_custom(name, message='Good morning')` that uses a default parameter value, and call it both with and without providing the second argument.

# %% [markdown]
# **Problem 64:** Write a function `sum_of_list(numbers)` that takes a list of numbers and returns their total sum.

# %% [markdown]
# **Problem 65:** Write a function `count_vowels(word)` that returns the number of vowels in a given word.

# %% [markdown]
# **Problem 66:** Write a function `is_palindrome(text)` that returns True if a given string reads the same forwards and backwards.

# %% [markdown]
# **Problem 67:** Write a function `calculate_area(shape, dim1, dim2=None)` that returns the area of a circle (only `dim1`=radius given) or a rectangle (`dim1`=length, `dim2`=width both given).

# %% [markdown]
# **Problem 68:** Write a function `simple_interest(principal, rate, time)` that returns the simple interest using the formula (P × R × T) / 100.

# %% [markdown]
# **Problem 69:** Write a lambda function that takes a number and returns its square, and use it to print the square of 7.

# %% [markdown]
# **Problem 70:** Write a function `fibonacci(n)` that returns a list containing the first n Fibonacci numbers.

# %% [markdown]
# ## Topic 7: Lists

# %% [markdown]
# **Problem 71:** Create a list of 5 fruits and print the entire list.

# %% [markdown]
# **Problem 72:** Write a program to access and print the first, middle, and last elements of a list.

# %% [markdown]
# **Problem 73:** Write a program to add a new item to the end of a list using `.append()`.

# %% [markdown]
# **Problem 74:** Write a program to remove a specific item from a list using `.remove()`.

# %% [markdown]
# **Problem 75:** Write a program to find the length of a list using `len()`.

# %% [markdown]
# **Problem 76:** Write a program to reverse a list using slicing (not a loop).

# %% [markdown]
# **Problem 77:** Write a program to sort a list of numbers in ascending order using `.sort()`.

# %% [markdown]
# **Problem 78:** Write a program to find the sum and average of all numbers in a list.

# %% [markdown]
# **Problem 79:** Write a program to find the largest and smallest numbers in a list without using `max()` or `min()`.

# %% [markdown]
# **Problem 80:** Write a program to count how many times a specific element appears in a list using `.count()`.

# %% [markdown]
# **Problem 81:** Write a program to check whether a given element exists in a list using the `in` keyword.

# %% [markdown]
# **Problem 82:** Write a program to merge two lists into one using the `+` operator.

# %% [markdown]
# **Problem 83:** Write a program to create a new list containing only the even numbers from an existing list.

# %% [markdown]
# **Problem 84:** Write a program to remove duplicate elements from a list while keeping the original order.

# %% [markdown]
# **Problem 85:** Write a program to create a list of squares of the numbers from 1 to 10 using a list comprehension.

# %% [markdown]
# ## Topic 8: Tuples

# %% [markdown]
# **Problem 86:** Create a tuple containing 5 numbers, and print the entire tuple.

# %% [markdown]
# **Problem 87:** Write a program to access the second and last elements of a tuple using indexing.

# %% [markdown]
# **Problem 88:** Write a program that attempts to modify a tuple's element, and print the error message that occurs.

# %% [markdown]
# **Problem 89:** Write a program to find the length of a tuple using `len()`.

# %% [markdown]
# **Problem 90:** Write a program to count the occurrences of a specific value in a tuple using `.count()`.

# %% [markdown]
# **Problem 91:** Write a program to find the index of a specific value in a tuple using `.index()`.

# %% [markdown]
# **Problem 92:** Write a program to unpack a tuple of three values into three separate variables.

# %% [markdown]
# **Problem 93:** Write a program to convert a list into a tuple, and a tuple into a list, using `tuple()` and `list()`.

# %% [markdown]
# **Problem 94:** Write a program to concatenate two tuples into one using the `+` operator.

# %% [markdown]
# **Problem 95:** Write a program to check whether a given value exists in a tuple using the `in` keyword.

# %% [markdown]
# ## Topic 9: Exception Handling

# %% [markdown]
# **Problem 96:** Write a program that divides two numbers taken as input, using try-except to handle the case where the user enters 0 as the divisor.

# %% [markdown]
# **Problem 97:** Write a program that takes a number as input, using try-except to handle the case where the user enters non-numeric text instead (catch ValueError).

# %% [markdown]
# **Problem 98:** Write a program that accesses a specific index of a list, using try-except to handle an IndexError if that index doesn't exist.

# %% [markdown]
# **Problem 99:** Write a program using try-except-else that attempts to convert a string to an integer, printing the result in the else block only if no error occurred.

# %% [markdown]
# **Problem 100:** Write a program using try-except-finally that attempts a division in try, catches any error in except, and always prints 'Operation attempted' in the finally block regardless of the outcome.

# %% [markdown]
# **Problem 101:** Write a program that uses a single except block to catch multiple possible exception types (ValueError and ZeroDivisionError) for one risky operation.

# %% [markdown]
# **Problem 102:** Write a program that deliberately raises a built-in exception using the `raise` keyword when a given age is negative.

# %% [markdown]
# **Problem 103:** Write a program that defines a custom exception class `NegativeNumberError` (inheriting from `Exception`) and raises it when a function receives a negative number.

# %% [markdown]
# **Problem 104:** Write a program using try-except to handle a KeyError when accessing a dictionary key that may not exist.

# %% [markdown]
# **Problem 105:** Write a program that repeatedly asks the user to enter a valid number, using a loop with try-except, until they successfully provide one.
